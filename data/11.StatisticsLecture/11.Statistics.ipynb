# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_diabetes

# %%
netflix_dataset = pd.read_csv('data/netflix_titles.csv', index_col='show_id')
netflix_dataset
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb              NaN
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
netflix_dataset.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
netflix_dataset.index
# Out:
# Index(['s1', 's2', 's3', 's4', 's5', 's6', 's7', 's8', 's9', 's10',
#        ...
#        's8798', 's8799', 's8800', 's8801', 's8802', 's8803', 's8804', 's8805',
#        's8806', 's8807'],
#       dtype='object', name='show_id', length=8807)

# %%
netflix_dataset.shape
# Out:
# (8807, 12)

# %% [markdown]
# Pandas does not mutate the original dataframe, except in_place=True. The methods return value:

# %%
netflix_dataset_mut = netdlix_dataset.drop(columns=['show_id'])
netflix_dataset_mut
# Out:
#          type                  title         director  \
# 0       Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1     TV Show          Blood & Water              NaN
# 2     TV Show              Ganglands  Julien Leclercq
# 3     TV Show  Jailbirds New Orleans              NaN
# 4     TV Show           Kota Factory              NaN
# ...       ...                    ...              ...
# 8802    Movie                 Zodiac    David Fincher
# 8803  TV Show            Zombie Dumb              NaN
# 8804    Movie             Zombieland  Ruben Fleischer
# 8805    Movie                   Zoom     Peter Hewitt
# 8806    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# ...

# %%
netflix_dataset_mut.release_year.min(), netflix_dataset_mut.release_year.max()
# Out:
# (1925, 2021)

# %%
plt.hist(netflix_dataset_mut.release_year, bins=30)
plt.show()

# %%
number_of_years = netflix_dataset_mut.release_year.nunique(dropna=True)
plt.hist(netflix_dataset_mut.release_year, bins=number_of_years)
plt.xlabel('Year')
plt.ylabel('Number of Movies')
plt.show()

# %%
netflix_dataset_mut[netflix_dataset_mut.release_year < 1960]
# Out:
#          type                                             title  \
# 542     Movie                                             Ujala
# 1331  TV Show               Five Came Back: The Reference Films
# 1699    Movie                                   White Christmas
# 2368    Movie                                     Cairo Station
# 2369    Movie                                       Dark Waters
# 2375    Movie                                   The Blazing Sun
# 4250  TV Show                 Pioneers: First Women Filmmakers*
# 6431    Movie                             Cat on a Hot Tin Roof
# 6784    Movie                                  Forbidden Planet
# 6853    Movie                                              Gigi
# 7219    Movie                           Know Your Enemy - Japan
# 7294    Movie                                Let There Be Light
# 7575    Movie                          Nazi Concentration Camps
# 7743  TV Show               Pioneers of African-American Cinema
# ...

# %%
netflix_dataset_mut[
    (netflix_dataset_mut.release_year >= 1960) &
    (netflix_dataset_mut.release_year < 1965)
]
# Out:
#          type                                title  \
# 177     Movie                 The Guns of Navarone
# 1126    Movie                         My Fair Lady
# 2373    Movie                              Saladin
# 5220    Movie                            Singapore
# 5400    Movie                            Professor
# 6395    Movie                        Butterfield 8
# 7133    Movie         Jis Desh Men Ganga Behti Hai
# 7332    Movie                               Lolita
# 7530    Movie                 Mutiny on the Bounty
# 7637    Movie                       Ocean's Eleven
# 7932    Movie                               Sangam
# 8541  TV Show  The Twilight Zone (Original Series)
#
#                          director  \
# 177               J. Lee Thompson
# 1126                 George Cukor
# 2373              Youssef Chahine
# 5220               Shakti Samanta
# 5400                  Lekh Tandon
# 6395                  Daniel Mann
# 7133               Radhu Karmakar
# ...

# %%
netflix_dataset_mut.title == 'Zodiac'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802     True
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Name: title, Length: 8807, dtype: bool

# %%
sixties_movies = netflix_dataset_mut[
    (netflix_dataset_mut.release_year >= 1960) &
    (netflix_dataset_mut.release_year <= 1970)
]
plt.hist(sixties_movies.release_year, bins=10)
plt.show()

# %%
hist_data = sixties_movies.release_year.value_counts().sort_index()

# %%
hist_data.values
# Out:
# array([4, 1, 3, 2, 2, 2, 1, 5, 3, 2, 2], dtype=int64)

# %%
hist_data.index
# Out:
# Index([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970], dtype='int64', name='release_year')

# %%
plt.bar(hist_data.index, hist_data)
plt.xticks(range(1960, 1971))

plt.xlabel('Release Year')
plt.ylabel('Number of Movies')
plt.title('Sizties Movies')
plt.show()

# %%
netflix_dataset_mut.release_year.mean()
# Out:
# 2014.1801975701146

# %%
netflix_dataset_mut.release_year.value_counts().idxmax(), netflix_dataset_mut.release_year.value_counts().max(),
# Out:
# (2018, 1147)

# %%
netflix_dataset_mut.release_year.value_counts().mean()
# Out:
# 119.01351351351352

# %%
netflix_dataset_mut.release_year.value_counts()
# Out:
# release_year
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1959       1
# 1925       1
# 1961       1
# 1947       1
# 1966       1
# Name: count, Length: 74, dtype: int64

# %%
number_of_movies_per_year = netflix_dataset_mut.release_year.value_counts()

# %%
plt.hist(number_of_movies_per_year, bins=80)
plt.xlabel('Number of Movies')
plt.ylabel('Years')
plt.show()

# %%
number_of_movies_per_year.median()
# Out:
# 12.5

# %%
number_of_movies_per_year.sort_values()
# Out:
# release_year
# 1966       1
# 1959       1
# 1947       1
# 1961       1
# 1925       1
#         ...
# 2016     902
# 2020     953
# 2019    1030
# 2017    1032
# 2018    1147
# Name: count, Length: 74, dtype: int64

# %%
number_of_movies_per_year.mode()
# Out:
# 0    2
# Name: count, dtype: int64

# %%
number_of_movies_per_year.var() # Variance
# Out:
# 71279.41077378744

# %%
number_of_movies_per_year.std() # standart deviation
# Out:
# 266.98204204363157

# %%
number_of_movies_per_year.skew() # Asymmetry of the distribution
# Out:
# 2.8145604374491016

# %%
number_of_movies_per_year.kurt()
# Out:
# 6.999361367773572

# %%
netflix_dataset_mut.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
plt.boxplot(netflix_dataset_mut.release_year)
plt.show()

# %%
netflix_dataset_mut.type.unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
netflix_dataset_mut.type.value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
db = netflix_dataset_mut

# %%
db.groupby('type').release_year.mean()
# Out:
# type
# Movie      2013.121514
# TV Show    2016.605755
# Name: release_year, dtype: float64

# %%
for type, group_data in db.groupby('type'):
    plt.hist(group_data.release_year, bins=30, alpha=0.5, label=type)

plt.legend()
plt.xlabel("Year")
plt.ylabel("Items Count")
plt.show()

# %%
spotify = pd.read_csv('data/spotify-2023.csv', encoding='latin')

# %%
spotify
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
diab_ds = load_diabetes()

# %%
diab_ds.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'DESCR', 'feature_names', 'data_filename', 'target_filename', 'data_module'])

# %%
print(diab_ds['DESCR'])
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
# :Number of Instances: 442
#
# :Number of Attributes: First 10 columns are numeric predictive values
#
# :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
# :Attribute Information:
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
#     - s3      hdl, high-density lipoproteins
#     - s4      tch, total cholesterol / HDL
#     - s5      ltg, possibly log of serum triglycerides level
# ...

# %%
diab_ds['data']
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]])

# %%
database = diab_ds['data']
bmi = database[:, 2]
plt.hist(bmi)
plt.show()

# %%
bmi = pd.Series(bmi)

# %%
bmi.mean(), bmi.std(), bmi.skew()
# Out:
# (-2.2455642172282577e-16, 0.04761904761904761, 0.5981484879110457)

# %%
cholesterol_feat = database[:, [5, 6, 7]]

# %%
cholesterol_feat
# Out:
# array([[-0.03482076, -0.04340085, -0.00259226],
#        [-0.01916334,  0.07441156, -0.03949338],
#        [-0.03419447, -0.03235593, -0.00259226],
#        ...,
#        [-0.01383982, -0.02499266, -0.01107952],
#        [ 0.01528299, -0.02867429,  0.02655962],
#        [ 0.02780893,  0.17381578, -0.03949338]])

# %%
ldl = database[:, 5]
hdl = database[:, 6]

# %%
plt.hist(ldl)
plt.hist(hdl)
plt.show()

# %%
plt.scatter(ldl, hdl)
plt.xlabel('ldl')
plt.ylabel('hdl')
plt.show()

# %%
np.corrcoef(hdl, bmi) # coeficiens of correlation, Pearson ro
# Out:
# array([[ 1.        , -0.36681098],
#        [-0.36681098,  1.        ]])
